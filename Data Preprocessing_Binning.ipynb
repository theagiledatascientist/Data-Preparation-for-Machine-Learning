# %% [markdown]
# ### Binning is the conversion of a continuous variable into a categorical variable

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#Loading Dataset
mpg = sns.load_dataset('mpg')
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
#.cut method - Fastest Method

# %%
# %%timeit

mpg['wt_cat_cut'] = pd.cut(np.array(mpg['weight']), 4, labels=["Light", "Medium", "Heavy", "Very heavy"])
# Out:
# 1.53 ms ± 146 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
mpg.sample(10)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 212  16.5          8         350.0       180.0    4380          12.1
# 112  19.0          4         122.0        85.0    2310          18.5
# 79   26.0          4          96.0        69.0    2189          18.0
# 37   18.0          6         232.0       100.0    3288          15.5
# 5    15.0          8         429.0       198.0    4341          10.0
# 44   13.0          8         400.0       175.0    5140          12.0
# 49   23.0          4         122.0        86.0    2220          14.0
# 238  33.5          4          98.0        83.0    2075          15.9
# 244  43.1          4          90.0        48.0    1985          21.5
# 321  32.2          4         108.0        75.0    2265          15.2
#
#      model_year  origin                             name  wt_cat_cut
# 212          76     usa                 cadillac seville  Very heavy
# 112          73     usa                       ford pinto       Light
# ...

# %%
# iterrows method

# %%
def apply_weights(weight): 
    if 1500 <= weight < 2500:
        category = 'Light'
    elif 2500 <= weight < 3500:
        category = 'Medium'
    elif 3500 <= weight < 4500:
        category = 'Heavy'
    else:
        category = 'Very heavy'
    return category

# %%
# %%timeit

cat_list = []
for index, row in mpg.iterrows():
    wt = row['weight']    
    cat = apply_weights(wt)
    cat_list.append(cat)
#print(len(cat_list))
mpg['Wt_Categories_iter'] = cat_list
# Out:
# 29.7 ms ± 1.77 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
mpg.sample(10)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 357  32.9          4         119.0       100.0    2615          14.8
# 14   24.0          4         113.0        95.0    2372          15.0
# 322  46.6          4          86.0        65.0    2110          17.9
# 144  31.0          4          76.0        52.0    1649          16.5
# 328  30.0          4         146.0        67.0    3250          21.8
# 130  26.0          4         122.0        80.0    2451          16.5
# 233  29.0          4          97.0        78.0    1940          14.5
# 170  23.0          4         140.0        78.0    2592          18.5
# 92   13.0          8         351.0       158.0    4363          13.0
# 340  25.8          4         156.0        92.0    2620          14.4
#
#      model_year  origin                      name  wt_cat_cut  \
# 357          81   japan              datsun 200sx      Medium
# 14           70   japan     toyota corona mark ii       Light
# ...
